# %%
import json
import requests
import openai
from openai.types.chat import ChatCompletionMessage

movie_url = "https://nomad-movies.nomadcoders.workers.dev"
client = openai.OpenAI()
messages = []


def get_popular_movies():
    try:
        response = requests.get(movie_url + "/movies")
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        return f"Error fetching movies: {e}"


def get_movie_details(id):
    try:
        response = requests.get(f"{movie_url}/movies/{id}")
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        return f"Error fetching movie details: {e}"


def get_similar_movies(id):
    try:
        response = requests.get(f"{movie_url}/movies/{id}/similar")
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        return f"Error fetching movie details: {e}"


FUNCTION_MAP = {
    "get_popular_movies": get_popular_movies,
    "get_movie_details": get_movie_details,
    "get_similar_movies": get_similar_movies,
}


TOOLS = [
    {
        "type": "function",
        "function": {
            "name": "get_popular_movies",
            "description": "Get a list of popular movies and their ids. Use this first when you only know the movie title and need to look up its id.",
        },
    },
    {
        "type": "function",
        "function": {
            "name": "get_movie_details",
            "description": "Get detailed information about a movie by id. The id must come from a previous tool call such as get_popular_movies; never make up an id.",
            "parameters": {
                "type": "object",
                "properties": {
                    "id": {
                        "type": "string",
                        "description": "The id of the movie, taken from the results of get_popular_movies or another tool output.",
                    }
                },
                "required": ["id"],
            },
        },
    },
    {
        "type": "function",
        "function": {
            "name": "get_similar_movies",
            "description": "Get similar movies given a movie id. The id must come from a previous tool call such as get_popular_movies or get_movie_details; never make up an id.",
            "parameters": {
                "type": "object",
                "properties": {
                    "id": {
                        "type": "string",
                        "description": "The id of the movie, taken from the results of get_popular_movies or another tool output.",
                    }
                },
                "required": ["id"],
            },
        },
    },
]


def process_ai_response(message: ChatCompletionMessage):
    if message.tool_calls:
        messages.append(
            {
                "role": "assistant",
                "content": message.content or "",
                "tool_calls": [
                    {
                        "id": tool_call.id,
                        "type": "function",
                        "function": {
                            "name": tool_call.function.name,
                            "arguments": tool_call.function.arguments,
                        },
                    }
                    for tool_call in message.tool_calls
                ],
            }
        )

        for tool_call in message.tool_calls:
            function_name = tool_call.function.name
            arguments = tool_call.function.arguments
            print(f"calling Function: {function_name} with arguments: {arguments}")

            try:
                arguments = json.loads(arguments)
            except json.JSONDecodeError:
                arguments = {}

            function_to_run = FUNCTION_MAP.get(function_name)
            result = function_to_run(**arguments)

            if isinstance(result, str):
                content = result
            else:
                content = json.dumps(result)

            messages.append(
                {
                    "role": "tool",
                    "tool_call_id": tool_call.id,
                    "name": function_name,
                    "content": content,
                }
            )

        call_ai()
    else:
        messages.append({"role": "assistant", "content": message.content})


def call_ai():
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=messages,
        tools=TOOLS,
    )
    message = response.choices[0].message

    # Print in the requested format
    if message.tool_calls:
        tool_names = ", ".join(
            f"{tool_call.function.name}()" for tool_call in message.tool_calls
        )
        print(f"Agent: [{tool_names} called]")

    print(f"Agent: {message.content}")
    process_ai_response(message)


while True:
    message = input("Send a message to llm")
    if message == "quit":
        break
    else:
        messages.append({"role": "user", "content": message})
        print(f"User: {message}")
        call_ai()
# Out:
# User: Tell me current popluar movies
# Agent: [get_popular_movies() called]
# Agent: None
# calling Function: get_popular_movies with arguments: {}
# Agent: Here are some of the current popular movies along with their details:
#
# 1. **Shelter**
#    - **Release Date:** January 28, 2026
#    - **Overview:** A man living in self-imposed exile on a remote island rescues a young girl from a violent storm, setting off a chain of events that forces him out of seclusion to protect her from enemies tied to his past.
#    - **Vote Average:** 6.957
#    - **Poster:** ![Shelter](https://image.tmdb.org/t/p/w780/buPFnHZ3xQy6vZEHxbHgL1Pc6CR.jpg)
#
# 2. **Mercy**
#    - **Release Date:** January 20, 2026
#    - **Overview:** In the near future, a detective stands on trial accused of murdering his wife. He has ninety minutes to prove his innocence to the advanced AI Judge he once championed, before it determines his fate.
#    - **Vote Average:** 7.1
#    - **Poster:** ![Mercy](https://image.tmdb.org/t/p/w780/pyok1kZJCfyuFapYXzHcy7BLlQa.jpg)
#
# 3. **The Orphans**
#    - **Release Date:** August 20, 2025
#    - **Overview:** Gab and Driss, childhood friends on bad terms since they left the orphanage, must stop Leïla before she crosses a line seeking revenge for her mother's suspicious death.
#    - **Vote Average:** 6.182
#    - **Poster:** ![The Orphans](https://image.tmdb.org/t/p/w780/hP7mjZr2SVfjAorlRHTdV1XZmHY.jpg)
#
# 4. **The Bluff**
#    - **Release Date:** February 17, 2026
#    - **Overview:** A skilled ex-pirate confronts her bloody past to protect her family from a vengeful former captain who returns to her remote island.
#    - **Vote Average:** 5.826
#    - **Poster:** ![The Bluff](https://image.tmdb.org/t/p/w780/sojEzvfxR2DBcDSJyAisX8TWjov.jpg)
#
# 5. **A Woman Scorned**
#    - **Release Date:** June 9, 2025
#    - **Overview:** After her sister is murdered by a group of local men, Jas is instilled with grief and fury, seeking justice at any cost.
#    - **Vote Average:** 6.333
#    - **Poster:** ![A Woman Scorned](https://image.tmdb.org/t/p/w780/dlOSBiNULMPzKIze84LDjvEN9z1.jpg)
#
# 6. **Hellfire**
#    - **Release Date:** February 5, 2026
#    - **Overview:** A drifter arrives in a small town and finds the residents under the grip of a crime boss, realizing he must help them.
#    - **Vote Average:** 7.118
#    - **Poster:** ![Hellfire](https://image.tmdb.org/t/p/w780/tQti9QTf13MfzNpXguijgNh7ojE.jpg)
#
# 7. **28 Years Later: The Bone Temple**
#    - **Release Date:** January 14, 2026
#    - **Overview:** Dr. Kelson navigates a shocking new relationship while confronting a threatening past.
#    - **Vote Average:** 7.2
#    - **Poster:** ![28 Years Later](https://image.tmdb.org/t/p/w780/kK1BGkG3KAvWB0WMV1DfOx9yTMZ.jpg)
#
# 8. **Your Heart Will Be Broken**
#    - **Release Date:** March 26, 2026
#    - **Overview:** A high school student makes a deal to protect herself from bullies, leading to unexpected developments in her life.
#    - **Vote Average:** 0
#    - **Poster:** ![Your Heart Will Be Broken](https://image.tmdb.org/t/p/w780/iGpMm603GUKH2SiXB2S5m4sZ17t.jpg)
#
# 9. **The Shadow's Edge**
#    - **Release Date:** August 16, 2025
#    - **Overview:** Macau Police calls back a retired tracking expert to help catch dangerous thieves.
#    - **Vote Average:** 7.243
#    - **Poster:** ![The Shadow's Edge](https://image.tmdb.org/t/p/w780/e0RU6KpdnrqFxDKlI3NOqN8nHL6.jpg)
#
# 10. **Zootopia 2**
#     - **Release Date:** November 26, 2025
#     - **Overview:** Judy Hopps and Nick Wilde uncover a new mystery in Zootopia involving unexpected challenges.
#     - **Vote Average:** 7.606
#     - **Poster:** ![Zootopia 2](https://image.tmdb.org/t/p/w780/oJ7g2CifqpStmoYQyaLQgEU32qO.jpg)
#
# Feel free to ask for more information about any specific movie!
# User: Tell me about Shelter
# Agent: [get_movie_details() called]
# Agent: None
# calling Function: get_movie_details with arguments: {"id":"1290821"}
# Agent: ### Shelter
#
# - **Release Date:** January 28, 2026
# - **Genre:** Action, Crime, Thriller
# - **Runtime:** 107 minutes
# - **Tagline:** Her safety. His mission.
# - **Overview:** A man living in self-imposed exile on a remote island rescues a young girl from a violent storm. This event sets off a chain of incidents that forces him out of seclusion to protect her from enemies connected to his past.
# - **Budget:** $50,000,000
# - **Revenue:** $26,786,795
# - **Vote Average:** 7.0 (from 114 votes)
# - **Original Language:** English
# - **Origin Countries:** United States, United Kingdom
#
# #### Production Companies:
# - **Black Bear Pictures** ![Black Bear Pictures](https://image.tmdb.org/t/p/w300/v37N1mFeXNQfvPankg3feBhVvM7.png)
# - **Punch Palace Productions** ![Punch Palace Productions](https://image.tmdb.org/t/p/w300null)
# - **CineMachine** ![CineMachine](https://image.tmdb.org/t/p/w300null)
# - **Stampede Ventures** ![Stampede Ventures](https://image.tmdb.org/t/p/w300/vafYjvjZwK4JaV5Hcm9vSzw6f9G.png)
#
# #### Additional Links:
# - **Homepage:** [Shelter](https://blackbearpictures.com/film-and-tv/shelter)
#
# #### Poster:
# ![Shelter](https://image.tmdb.org/t/p/w780/buPFnHZ3xQy6vZEHxbHgL1Pc6CR.jpg)
#
# If you would like to know more details or ask other questions, feel free to let me know!
# User: Can you recommend similar movies?
# Agent: [get_similar_movies() called]
# Agent: None
# calling Function: get_similar_movies with arguments: {"id":"1290821"}
# Agent: Here are some movies similar to **Shelter**:
#
# 1. **Roseville**
#    - **Release Date:** December 20, 2013
#    - **Overview:** A young couple encounters unexplained events during their stay at an isolated mountain hut, testing their sanity with hidden horrors.
#    - **Vote Average:** 5.591
#    - **Poster:** ![Roseville](https://image.tmdb.org/t/p/w780/mmQnPUUdw6a1D9kkmDPRDQK08zj.jpg)
#
# 2. **Backtrack**
#    - **Release Date:** July 25, 2015
#    - **Overview:** A troubled psychotherapist uncovers a horrifying secret shared by his patients, leading him back to confront his past.
#    - **Vote Average:** 5.777
#    - **Poster:** ![Backtrack](https://image.tmdb.org/t/p/w780/8L4jifugHPASkrssmOUVdQxn3WN.jpg)
#
# 3. **Esther's Choice**
#    - **Release Date:** October 15, 2020
#    - **Overview:** A film composer moving in with her boyfriend faces emotional turmoil as she finds old belongings of his ex-girlfriend.
#    - **Vote Average:** 0
#    - **Poster:** ![Esther's Choice](https://image.tmdb.org/t/p/w780/t7jJv2tE2w06zJ8JAzNVeJKZyBH.jpg)
#
# 4. **Vesper**
#    - **Release Date:** March 20, 2017
#    - **Overview:** A woman seeks help from her nephew to protect herself against her sinister husband, uncovering dark secrets along the way.
#    - **Vote Average:** 6
#    - **Poster:** ![Vesper](https://image.tmdb.org/t/p/w780/7zLjzG6PWX5KeTl0gWJbehz5Lq8.jpg)
#
# 5. **House of Bad**
#    - **Release Date:** May 18, 2013
#    - **Overview:** Three sisters try to escape their past by hiding out in their old family house, which holds painful memories.
#    - **Vote Average:** 2.889
#    - **Poster:** ![House of Bad](https://image.tmdb.org/t/p/w780/dmEyr8CGwR5fbRqMN0tjTURLKHg.jpg)
#
# 6. **Haunted 5: Phantoms**
#    - **Release Date:** December 22, 2020
#    - **Overview:** A private investigator returns to investigate paranormal events in a London pub, confronting ghosts and phantoms.
#    - **Vote Average:** 10
#    - **Poster:** ![Haunted 5: Phantoms](https://image.tmdb.org/t/p/w780/16kXIdVyqGBF0WViQlxm24faYUv.jpg)
#
# 7. **A Christmas Carol**
#    - **Release Date:** October 9, 1984
#    - **Overview:** Miser Ebenezer Scrooge is forced to confront his misdeeds by spirits on Christmas Eve, leading him to seek redemption.
#    - **Vote Average:** 7.5
#    - **Poster:** ![A Christmas Carol](https://image.tmdb.org/t/p/w780/m3T3iLdE6J5PrqvvP0XNHBvM2bm.jpg)
#
# 8. **Skeleton**
#    - **Release Date:** May 17, 2019
#    - **Overview:** A woman is drawn back to her childhood home, where she unravels the truth behind her younger sister's fate.
#    - **Vote Average:** 0
#    - **Poster:** ![Skeleton](https://image.tmdb.org/t/p/w780/y845NhdD7Or85kwrvufZ9HprchF.jpg)
#
# Each of these films touches on themes of suspense, hidden truths, and confronting the past, similar to "Shelter." Let me know if you want more details about any of these movies!
