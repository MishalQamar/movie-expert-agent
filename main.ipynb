# %%
from openai import OpenAI

client = openai.OpenAI()

PROMPT = """
You are a Movie Expert Agent. I have following functions in my system

1. get_popular_movies() - returns popular movies. This function takes NO arguments.
2. get_movie_details(id) - returns details of a movie. This function requires ONE argument: id (integer).
3. get_movie_credits(id) - returns the cast & crew of a movie. This function requires ONE argument: id (integer).

Instructions:
- Read the user's question
- Decide which function to call
- Output ONLY the function name and arguments

Answer the following question:
Tell me what movie corresponds to the movie ID 550
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": PROMPT}],
    max_tokens=40,
    temperature=0,
)

message = response.choices[0].message.content
print(message)
